# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]
bar = plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data', alpha=0.8)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Top 5 Languages for Math & Data')

# %%
ax = plt.gca()

#y축 tick,label제거
ax.axes.yaxis.set_visible(False)

#테투리 제거
plt.box(False)

#x축 tick을 숨김
plt.tick_params(axis='x', direction='out', color ='w')

#python을 제외한 나머지를 회색으로 바꿔줌
plt.bar(pos[1:], popularity[1:], align='center', color='gray')

# 퍼센트를 적어줌
for i,p in enumerate(bar):
    height = p.get_height()
    width = p.get_width()
    ax.text(p.get_x() + width/2, height-5,
           "%.0f%%"%(popularity[i]),ha='center', va='bottom', color='white')

# %%
# 1st condition
plt.tick_params(top = False, bottom=False, left = False, right = False, labelleft=False, labelbottom=True)
plt.ylabel('')
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# %%
# 2nd condition
bars = plt.gca().patches
for bar in bars:
    bar.set_color('lightgray')

bars[0].set_color('blue')

# %%
# 3rd condition
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height()-5,
                  str(int(bar.get_height()))+'%', ha='center', color='w', fontsize = 11)
