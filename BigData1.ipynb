# %%
import pandas as pd

purchase_1 = pd.Series({'Name' : 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost' : 22.50})
purchase_2 = pd.Series({'Name' : 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost' : 2.50})
purchase_3 = pd.Series({'Name' : 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost' : 5.0})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index = ['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df.loc['Store 1'] #두가지 serise를 하나로 봄
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5

# %%
df.loc[:,['Name','Cost']] #원하는 것만 골라 볼 수 있음
# Out:
#           Name  Cost
# Store 1  Chris  22.5
# Store 1  Kevyn   2.5
# Store 2  Vinod   5.0

# %%
# update value
costs = df['Cost']
costs
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
costs += 2

# %%
costs
# Out:
# Store 1    24.5
# Store 1     4.5
# Store 2     7.0
# Name: Cost, dtype: float64

# %%
df # 안바뀌는 이유를 모르겠습니다...
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
# Dataframe Indexing and Loading

# %%
df = pd.read_csv('olympics.csv')
df.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df = pd.read_csv('olympics.csv', index_col=0, skiprows = 1)
df.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
for col in df.columns:
    if col[:2] == '01':
        df.rename(columns = {col:'Gold' + col[4:]}, inplace=True)
    if col[:2] == '02':
        df.rename(columns = {col:'Silver' + col[4:]}, inplace=True)
    if col[:2] == '03':
        df.rename(columns = {col:'Bronze' + col[4:]}, inplace=True)
    if col[:1] == '№':
        df.rename(columns = {col:'#' + col[1:]}, inplace=True)

df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
# Querying a Dataframe

# %%
df['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
#                                                 ...
# Independent Olympic Participants (IOP) [IOP]    False
# Zambia (ZAM) [ZAM]                              False
# Zimbabwe (ZIM) [ZIM]                             True
# Mixed team (ZZX) [ZZX]                           True
# Totals                                           True
# Name: Gold, Length: 147, dtype: bool

# %%
only_gold = df.where(df['Gold']>0)
only_gold.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)             NaN   NaN     NaN     NaN    NaN       NaN
# Algeria (ALG)                12.0   5.0     2.0     8.0   15.0       3.0
# Argentina (ARG)              23.0  18.0    24.0    28.0   70.0      18.0
# Armenia (ARM)                 5.0   1.0     2.0     9.0   12.0       6.0
# Australasia (ANZ) [ANZ]       2.0   3.0     4.0     5.0   12.0       0.0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)           NaN       NaN       NaN      NaN      NaN     NaN
# Algeria (ALG)               0.0       0.0       0.0      0.0     15.0     5.0
# Argentina (ARG)             0.0       0.0       0.0      0.0     41.0    18.0
# Armenia (ARM)               0.0       0.0       0.0      0.0     11.0     1.0
# Australasia (ANZ) [ANZ]     0.0       0.0       0.0      0.0      2.0     3.0
#
# ...

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
only_gold.count() #gold가 0보다 큰 나라의 갯수
# Out:
# # Summer          100
# Gold              100
# Silver            100
# Bronze            100
# Total             100
# # Winter          100
# Gold.1            100
# Silver.1          100
# Bronze.1          100
# Total.1           100
# # Games           100
# Gold.2            100
# Silver.2          100
# Bronze.2          100
# Combined total    100
# dtype: int64

# %%
df.count() # 전체 갯수
# Out:
# # Summer          147
# Gold              147
# Silver            147
# Bronze            147
# Total             147
# # Winter          147
# Gold.1            147
# Silver.1          147
# Bronze.1          147
# Total.1           147
# # Games           147
# Gold.2            147
# Silver.2          147
# Bronze.2          147
# Combined total    147
# dtype: int64

# %%
only_gold = only_gold.dropna()
only_gold
# Out:
#                            # Summer    Gold  Silver  Bronze    Total  \
# Algeria (ALG)                  12.0     5.0     2.0     8.0     15.0
# Argentina (ARG)                23.0    18.0    24.0    28.0     70.0
# Armenia (ARM)                   5.0     1.0     2.0     9.0     12.0
# Australasia (ANZ) [ANZ]         2.0     3.0     4.0     5.0     12.0
# Australia (AUS) [AUS] [Z]      25.0   139.0   152.0   177.0    468.0
# ...                             ...     ...     ...     ...      ...
# Venezuela (VEN)                17.0     2.0     2.0     8.0     12.0
# Yugoslavia (YUG) [YUG]         16.0    26.0    29.0    28.0     83.0
# Zimbabwe (ZIM) [ZIM]           12.0     3.0     4.0     1.0      8.0
# Mixed team (ZZX) [ZZX]          3.0     8.0     5.0     4.0     17.0
# Totals                         27.0  4809.0  4775.0  5130.0  14714.0
#
#                            # Winter  Gold.1  Silver.1  Bronze.1  Total.1  \
# ...

# %%
only_gold1 = df[df['Gold']>0]
only_gold1.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Algeria (ALG)                    12     5       2       8     15         3
# Argentina (ARG)                  23    18      24      28     70        18
# Armenia (ARM)                     5     1       2       9     12         6
# Australasia (ANZ) [ANZ]           2     3       4       5     12         0
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Algeria (ALG)                   0         0         0        0       15
# Argentina (ARG)                 0         0         0        0       41
# Armenia (ARM)                   0         0         0        0       11
# Australasia (ANZ) [ANZ]         0         0         0        0        2
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
both_gold = df[(df['Gold']>0) & (df['Gold.1']>0)]
both_gold.head()
# Out:
#                            # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Australia (AUS) [AUS] [Z]        25   139     152     177    468        18
# Austria (AUT)                    26    18      33      35     86        22
# Belarus (BLR)                     5    12      24      39     75         6
# Belgium (BEL)                    25    37      52      53    142        20
# Bulgaria (BUL) [H]               19    51      85      78    214        19
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  # Games  \
# Australia (AUS) [AUS] [Z]       5         3         4       12       43
# Austria (AUT)                  59        78        81      218       48
# Belarus (BLR)                   6         4         5       15       11
# Belgium (BEL)                   1         1         3        5       45
# Bulgaria (BUL) [H]              1         2         3        6       38
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
len(both_gold)
# Out:
# 37

# %%
any_gold = df[(df['Gold']>0) | (df['Gold.1']>0)]
len(any_gold)
# Out:
# 101

# %%
any_gold1 = df[(df['Gold'] == 0) & (df['Gold.1']>0)]
any_gold1
# Out:
#                      # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Liechtenstein (LIE)        16     0       0       0      0        18       2
#
#                      Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9       34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %%
#Indexing Dataframes

# %%
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df['country'] = df.index
df.head()
# Out:
#                          # Summer  Gold  Silver  Bronze  Total  # Winter  \
# Afghanistan (AFG)              13     0       0       2      2         0
# Algeria (ALG)                  12     5       2       8     15         3
# Argentina (ARG)                23    18      24      28     70        18
# Armenia (ARM)                   5     1       2       9     12         6
# Australasia (ANZ) [ANZ]         2     3       4       5     12         0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  # Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0       13       0
# Algeria (ALG)                 0         0         0        0       15       5
# Argentina (ARG)               0         0         0        0       41      18
# Armenia (ARM)                 0         0         0        0       11       1
# Australasia (ANZ) [ANZ]       0         0         0        0        2       3
#
# ...

# %%
df = df.set_index('Combined total')
df.head()
# Out:
#                 # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Combined total
# 2                     13     0       0       2      2         0       0
# 15                    12     5       2       8     15         3       0
# 70                    23    18      24      28     70        18       0
# 12                     5     1       2       9     12         6       0
# 12                     2     3       4       5     12         0       0
#
#                 Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# Combined total
# 2                      0         0        0       13       0         0
# 15                     0         0        0       15       5         2
# 70                     0         0        0       41      18        24
# 12                     0         0        0       11       1         2
# 12                     0         0        0        2       3         4
#
#                 Bronze.2                  country
# Combined total
# ...

# %%
df = df.sort_index()
df
# Out:
#                 # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Combined total
# 1                     13     0       0       1      1         0       0
# 1                     13     0       1       0      1         1       0
# 1                     11     0       1       0      1         0       0
# 1                      9     0       1       0      1         0       0
# 1                     16     0       0       1      1         0       0
# ...                  ...   ...     ...     ...    ...       ...     ...
# 782                   15   174     182     217    573        11      78
# 806                   27   236     272     272    780        22      10
# 1204                   9   395     319     296   1010         9      78
# 2681                  26   976     757     666   2399        22      96
# 17579                 27  4809    4775    5130  14714        22     959
#
#                 Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  \
# ...

# %%
df = df.reset_index() #  index를 순서대로 매겨줌 
df
# Out:
#      Combined total  # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# 0                 1        13     0       0       1      1         0       0
# 1                 1        13     0       1       0      1         1       0
# 2                 1        11     0       1       0      1         0       0
# 3                 1         9     0       1       0      1         0       0
# 4                 1        16     0       0       1      1         0       0
# ..              ...       ...   ...     ...     ...    ...       ...     ...
# 142             782        15   174     182     217    573        11      78
# 143             806        27   236     272     272    780        22      10
# 144            1204         9   395     319     296   1010         9      78
# 145            2681        26   976     757     666   2399        22      96
# 146           17579        27  4809    4775    5130  14714        22     959
#
# ...

# %%
df
# Out:
#      Combined total  # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# 0                 1        13     0       0       1      1         0       0
# 1                 1        13     0       1       0      1         1       0
# 2                 1        11     0       1       0      1         0       0
# 3                 1         9     0       1       0      1         0       0
# 4                 1        16     0       0       1      1         0       0
# ..              ...       ...   ...     ...     ...    ...       ...     ...
# 142             782        15   174     182     217    573        11      78
# 143             806        27   236     272     272    780        22      10
# 144            1204         9   395     319     296   1010         9      78
# 145            2681        26   976     757     666   2399        22      96
# 146           17579        27  4809    4775    5130  14714        22     959
#
# ...

# %%
purchase_1 = pd.Series({'Name' : 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost' : 22.50})
purchase_2 = pd.Series({'Name' : 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost' : 2.50})
purchase_3 = pd.Series({'Name' : 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost' : 5.0})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index = ['Store 1', 'Store 1', 'Store 2'])
df.head()
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris       Dog Food  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Vinod      Bird Seed   5.0

# %%
df['store'] = df.index
df
# Out:
#           Name Item Purchased  Cost    store
# Store 1  Chris       Dog Food  22.5  Store 1
# Store 1  Kevyn   Kitty Litter   2.5  Store 1
# Store 2  Vinod      Bird Seed   5.0  Store 2

# %%
df = df.reset_index()
df
# Out:
#      index   Name Item Purchased  Cost    store
# 0  Store 1  Chris       Dog Food  22.5  Store 1
# 1  Store 1  Kevyn   Kitty Litter   2.5  Store 1
# 2  Store 2  Vinod      Bird Seed   5.0  Store 2

# %%
df = df.drop('index', axis=1)
df
# Out:
#     Name Item Purchased  Cost    store
# 0  Chris       Dog Food  22.5  Store 1
# 1  Kevyn   Kitty Litter   2.5  Store 1
# 2  Vinod      Bird Seed   5.0  Store 2

# %%
df1 = df.reset_index(drop = True) # index를 바로 drop해서 만드는법
df1
# Out:
#     Name Item Purchased  Cost    store
# 0  Chris       Dog Food  22.5  Store 1
# 1  Kevyn   Kitty Litter   2.5  Store 1
# 2  Vinod      Bird Seed   5.0  Store 2

# %%
df['store']
# Out:
# 0    Store 1
# 1    Store 1
# 2    Store 2
# Name: store, dtype: object

# %%
df['store'].unique()
# Out:
# array(['Store 1', 'Store 2'], dtype=object)

# %%
df = df.set_index(['store','Name'])
df
# Out:
#               Item Purchased  Cost
# store   Name
# Store 1 Chris       Dog Food  22.5
#         Kevyn   Kitty Litter   2.5
# Store 2 Vinod      Bird Seed   5.0

# %%
df.loc['Store 1', 'Chris']
# Out:
# Item Purchased    Dog Food
# Cost                  22.5
# Name: (Store 1, Chris), dtype: object
